# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
field = '/content/drive/My Drive/water-quality/field_results.csv'

field_df = pd.read_csv(field,low_memory=False)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # DATA UNDERSTANDING

# %%
# Dimensions of the dataset

field_df.shape
# Out:
# (1217203, 22)

# %%
# Column names

field_df.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'status', 'county_name',
#        'sample_code', 'sample_date', 'sample_depth', 'sample_depth_units',
#        'anl_data_type', 'parameter', 'fdr_result', 'fdr_text_result',
#        'fdr_date_result', 'fdr_reporting_limit', 'uns_name', 'mth_name',
#        'fdr_footnote'],
#       dtype='object')

# %%
# First few rows

field_df.head()
# Out:
#    station_id          station_name station_number  \
# 0          12  H.O. Banks Headworks       KA000331
# 1          12  H.O. Banks Headworks       KA000331
# 2          12  H.O. Banks Headworks       KA000331
# 3          12  H.O. Banks Headworks       KA000331
# 4          12  H.O. Banks Headworks       KA000331
#
#                        full_station_name   station_type  latitude  longitude  \
# 0  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 1  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 2  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 3  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 4  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
#
#                           status county_name  sample_code  \
# 0  Public, Review Status Unknown     Alameda  OM0168A0001
# 1  Public, Review Status Unknown     Alameda  OM0168A0001
# 2  Public, Review Status Unknown     Alameda  OM0168A0001
# 3  Public, Review Status Unknown     Alameda  OM0168A0001
# 4  Public, Review Status Unknown     Alameda  OM0268A0006
#
#            sample_date  sample_depth sample_depth_units anl_data_type  \
# 0  1968-01-04 07:45:00           1.0               Feet           NaN
# 1  1968-01-04 07:45:00           1.0               Feet           NaN
# 2  1968-01-04 07:45:00           1.0               Feet           NaN
# 3  1968-01-04 07:45:00           1.0               Feet           NaN
# 4  1968-02-01 08:10:00           1.0               Feet           NaN
#
#                parameter  fdr_result fdr_text_result fdr_date_result  \
# 0        DissolvedOxygen         9.2             NaN             NaN
# 1  ElectricalConductance       515.0             NaN             NaN
# 2       WaterTemperature         6.7             NaN             NaN
# 3                     pH         7.3             NaN             NaN
# 4        DissolvedOxygen         9.7             NaN             NaN
#
#    fdr_reporting_limit  uns_name                   mth_name fdr_footnote
# 0                  0.2      mg/L          EPA 360.2 (Field)          NaN
# 1                  1.0     uS/cm  Std Method 2510-B (Field)          NaN
# 2                  0.1        °C          EPA 170.1 (Field)          NaN
# 3                  0.1  pH Units          EPA 150.1 (Field)          NaN
# 4                  0.2      mg/L          EPA 360.2 (Field)          NaN

# %%
# last few rows

field_df.tail()
# Out:
#          station_id  station_name station_number full_station_name  \
# 1217198       48167  PMW-34b Deep  16N05E30A501M     16N05E30A501M
# 1217199       48167  PMW-34b Deep  16N05E30A501M     16N05E30A501M
# 1217200       48167  PMW-34b Deep  16N05E30A501M     16N05E30A501M
# 1217201       48167  PMW-34b Deep  16N05E30A501M     16N05E30A501M
# 1217202       48167  PMW-34b Deep  16N05E30A501M     16N05E30A501M
#
#         station_type   latitude   longitude                         status  \
# 1217198  Groundwater  39.221383 -121.446028  Public, Review Status Unknown
# 1217199  Groundwater  39.221383 -121.446028  Public, Review Status Unknown
# 1217200  Groundwater  39.221383 -121.446028  Public, Review Status Unknown
# 1217201  Groundwater  39.221383 -121.446028  Public, Review Status Unknown
# 1217202  Groundwater  39.221383 -121.446028  Public, Review Status Unknown
#
#         county_name   sample_code          sample_date  sample_depth  \
# 1217198        Yuba  CH0724B00007  2024-07-09 16:15:00          70.0
# 1217199        Yuba  CH0724B00007  2024-07-09 16:15:00          70.0
# 1217200        Yuba  CH0724B00007  2024-07-09 16:15:00          70.0
# 1217201        Yuba  CH0724B00007  2024-07-09 16:15:00          70.0
# 1217202        Yuba  CH0724B00007  2024-07-09 16:15:00          70.0
#
#         sample_depth_units anl_data_type            parameter  fdr_result  \
# 1217198               Feet           NaN      DissolvedOxygen        2.65
# 1217199               Feet           NaN  SpecificConductance      299.00
# 1217200               Feet           NaN            Turbidity       93.10
# 1217201               Feet           NaN     WaterTemperature       24.50
# 1217202               Feet           NaN                   pH        7.51
#
#         fdr_text_result fdr_date_result  fdr_reporting_limit       uns_name  \
# 1217198             NaN             NaN                  NaN           mg/L
# 1217199             NaN             NaN                  NaN  µmhos/cm@25°C
# 1217200             NaN             NaN                  NaN         F.N.U.
# 1217201             NaN             NaN                  NaN             °C
# 1217202             NaN             NaN                  NaN       pH Units
#
#                               mth_name fdr_footnote
# 1217198  ASTM Method D888-09-C (Field)          NaN
# 1217199              EPA 120.1 (Field)          NaN
# 1217200               Turbidity, Sonde          NaN
# 1217201              EPA 170.1 (Field)          NaN
# 1217202       SM 4500-H B-2000 (Field)          NaN

# %%
# checking for missing values

field_df.isnull().sum()/field_df.shape[0]
# Out:
# station_id             0.000000
# station_name           0.000000
# station_number         0.000000
# full_station_name      0.000000
# station_type           0.000000
# latitude               0.010324
# longitude              0.010324
# status                 0.000000
# county_name            0.000000
# sample_code            0.000000
# sample_date            0.000000
# sample_depth           0.464255
# sample_depth_units     0.000000
# anl_data_type          0.887200
# parameter              0.000000
# fdr_result             0.107697
# fdr_text_result        0.897444
# fdr_date_result        0.996099
# fdr_reporting_limit    0.155756
# uns_name               0.000000
# mth_name               0.000007
# fdr_footnote           0.900046
# dtype: float64

# %% [markdown]
# There are some columns with more than 50 % of missing values, need to drop them

# %%
field_df.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'status', 'county_name',
#        'sample_code', 'sample_date', 'sample_depth', 'sample_depth_units',
#        'anl_data_type', 'parameter', 'fdr_result', 'fdr_text_result',
#        'fdr_date_result', 'fdr_reporting_limit', 'uns_name', 'mth_name',
#        'fdr_footnote'],
#       dtype='object')

# %%
field_df["station_id"].nunique()
# Out:
# 29371

# %%
field_df["station_name"].nunique()
# Out:
# 29236

# %% [markdown]
# Different station id's have same station name

# %%
field_df["station_number"].nunique() # every station id has same station number?
# Out:
# 29371

# %%
field_df["full_station_name"].nunique()
# Out:
# 29289

# %% [markdown]
# Station id, station name and station number together form unique identifier ?

# %%
field_df
# Out:
#          station_id          station_name station_number  \
# 0                12  H.O. Banks Headworks       KA000331
# 1                12  H.O. Banks Headworks       KA000331
# 2                12  H.O. Banks Headworks       KA000331
# 3                12  H.O. Banks Headworks       KA000331
# 4                12  H.O. Banks Headworks       KA000331
# ...             ...                   ...            ...
# 1217198       48167          PMW-34b Deep  16N05E30A501M
# 1217199       48167          PMW-34b Deep  16N05E30A501M
# 1217200       48167          PMW-34b Deep  16N05E30A501M
# 1217201       48167          PMW-34b Deep  16N05E30A501M
# 1217202       48167          PMW-34b Deep  16N05E30A501M
#
#                              full_station_name   station_type   latitude  \
# 0        Delta P.P. Headworks at H.O. Banks PP  Surface Water  37.801900
# 1        Delta P.P. Headworks at H.O. Banks PP  Surface Water  37.801900
# 2        Delta P.P. Headworks at H.O. Banks PP  Surface Water  37.801900
# 3        Delta P.P. Headworks at H.O. Banks PP  Surface Water  37.801900
# 4        Delta P.P. Headworks at H.O. Banks PP  Surface Water  37.801900
# ...                                        ...            ...        ...
# 1217198                          16N05E30A501M    Groundwater  39.221383
# 1217199                          16N05E30A501M    Groundwater  39.221383
# 1217200                          16N05E30A501M    Groundwater  39.221383
# 1217201                          16N05E30A501M    Groundwater  39.221383
# 1217202                          16N05E30A501M    Groundwater  39.221383
#
#           longitude                         status county_name   sample_code  \
# 0       -121.620300  Public, Review Status Unknown     Alameda   OM0168A0001
# 1       -121.620300  Public, Review Status Unknown     Alameda   OM0168A0001
# 2       -121.620300  Public, Review Status Unknown     Alameda   OM0168A0001
# 3       -121.620300  Public, Review Status Unknown     Alameda   OM0168A0001
# 4       -121.620300  Public, Review Status Unknown     Alameda   OM0268A0006
# ...             ...                            ...         ...           ...
# 1217198 -121.446028  Public, Review Status Unknown        Yuba  CH0724B00007
# 1217199 -121.446028  Public, Review Status Unknown        Yuba  CH0724B00007
# 1217200 -121.446028  Public, Review Status Unknown        Yuba  CH0724B00007
# 1217201 -121.446028  Public, Review Status Unknown        Yuba  CH0724B00007
# 1217202 -121.446028  Public, Review Status Unknown        Yuba  CH0724B00007
#
#                  sample_date  sample_depth sample_depth_units anl_data_type  \
# 0        1968-01-04 07:45:00           1.0               Feet           NaN
# 1        1968-01-04 07:45:00           1.0               Feet           NaN
# 2        1968-01-04 07:45:00           1.0               Feet           NaN
# 3        1968-01-04 07:45:00           1.0               Feet           NaN
# 4        1968-02-01 08:10:00           1.0               Feet           NaN
# ...                      ...           ...                ...           ...
# 1217198  2024-07-09 16:15:00          70.0               Feet           NaN
# 1217199  2024-07-09 16:15:00          70.0               Feet           NaN
# 1217200  2024-07-09 16:15:00          70.0               Feet           NaN
# 1217201  2024-07-09 16:15:00          70.0               Feet           NaN
# 1217202  2024-07-09 16:15:00          70.0               Feet           NaN
#
#                      parameter  fdr_result fdr_text_result fdr_date_result  \
# 0              DissolvedOxygen        9.20             NaN             NaN
# 1        ElectricalConductance      515.00             NaN             NaN
# 2             WaterTemperature        6.70             NaN             NaN
# 3                           pH        7.30             NaN             NaN
# 4              DissolvedOxygen        9.70             NaN             NaN
# ...                        ...         ...             ...             ...
# 1217198        DissolvedOxygen        2.65             NaN             NaN
# 1217199    SpecificConductance      299.00             NaN             NaN
# 1217200              Turbidity       93.10             NaN             NaN
# 1217201       WaterTemperature       24.50             NaN             NaN
# 1217202                     pH        7.51             NaN             NaN
#
#          fdr_reporting_limit       uns_name                       mth_name  \
# 0                        0.2           mg/L              EPA 360.2 (Field)
# 1                        1.0          uS/cm      Std Method 2510-B (Field)
# 2                        0.1             °C              EPA 170.1 (Field)
# 3                        0.1       pH Units              EPA 150.1 (Field)
# 4                        0.2           mg/L              EPA 360.2 (Field)
# ...                      ...            ...                            ...
# 1217198                  NaN           mg/L  ASTM Method D888-09-C (Field)
# 1217199                  NaN  µmhos/cm@25°C              EPA 120.1 (Field)
# 1217200                  NaN         F.N.U.               Turbidity, Sonde
# 1217201                  NaN             °C              EPA 170.1 (Field)
# 1217202                  NaN       pH Units       SM 4500-H B-2000 (Field)
#
#         fdr_footnote
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1217198          NaN
# 1217199          NaN
# 1217200          NaN
# 1217201          NaN
# 1217202          NaN
#
# [1217203 rows x 22 columns]

# %%
field_df.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'status', 'county_name',
#        'sample_code', 'sample_date', 'sample_depth', 'sample_depth_units',
#        'anl_data_type', 'parameter', 'fdr_result', 'fdr_text_result',
#        'fdr_date_result', 'fdr_reporting_limit', 'uns_name', 'mth_name',
#        'fdr_footnote'],
#       dtype='object')

# %%
field_df["station_type"].nunique()
# Out:
# 3

# %%
field_df["station_type"].value_counts()
# Out:
# station_type
# Surface Water    1092867
# Groundwater       121337
# Other               2999
# Name: count, dtype: int64

# %%
field_df["status"].nunique()  # can be dropped as there is no variance
# Out:
# 1

# %%
field_df['county_name'].nunique()
# Out:
# 58

# %% [markdown]
# For each sample date, there is a sample code for every station_id

# %%
# has negative values
field_df["sample_depth"].min(), field_df["sample_depth"].max()
# Out:
# (-0.34999999, 1615.0)

# %%
field_df["sample_depth_units"].value_counts()
# Out:
# sample_depth_units
# Feet      923649
# Meters    293286
# inches       268
# Name: count, dtype: int64

# %%
field_df["parameter"].nunique()
# Out:
# 65

# %% [markdown]
# - include all 65 parameters for analysis?

# %%
field_df["sample_date"].min(), field_df["sample_date"].max()
# Out:
# ('1913-05-13 13:30:00', '2025-07-08 12:30:00')

# %%
field_df.loc[field_df["sample_date"]>= '2025-01-01', 'station_id']
# Out:
# 6364          12
# 6365          12
# 6366          12
# 6367          12
# 6368          12
#            ...
# 1216882    45866
# 1216883    45866
# 1216884    45866
# 1216885    45866
# 1216886    45866
# Name: station_id, Length: 5111, dtype: int64

# %% [markdown]
# Viewing data distribution over time to see if complete data needs to be used or only a portion of it

# %%
df = field_df.copy()
df['year'] = pd.to_datetime(df['sample_date']).dt.year
df['year'].value_counts().sort_index().plot(kind='bar', figsize=(20,4))
# Out:
# <Axes: xlabel='year'>

# %%
import matplotlib.pyplot as plt

df = field_df.copy()
df['year'] = pd.to_datetime(df['sample_date']).dt.year

# Prepare the plot
ax = df['year'].value_counts().sort_index().plot(kind='bar', figsize=(20, 4))
ax.set_xlabel('Year of Sample Collection', fontsize=12)
ax.set_ylabel('Number of Samples', fontsize=12)
ax.set_title('Annual Distribution of Water Quality Samples (1913–2025)', fontsize=14)

# Show only every 5th year label
tick_positions = range(len(ax.get_xticks()))
tick_labels = [label.get_text() for label in ax.get_xticklabels()]
ax.set_xticks(tick_positions[::5])
ax.set_xticklabels(tick_labels[::5], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Pre-1950 data is sparse → not statistically useful.
# - 1950–1985 data is dense but methodologically different (analog instruments, older standards).
# - 2000–2025 is consistent and digital → ideal for ML models.

# %% [markdown]
# Considering data after 2000 for further analysis and training the model

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# **Filtering data after year 2000**

# %%
field_df["sample_date"] = pd.to_datetime(field_df["sample_date"], errors= 'coerce')

# %%
field_df.dtypes
# Out:
# station_id                      int64
# station_name                   object
# station_number                 object
# full_station_name              object
# station_type                   object
# latitude                      float64
# longitude                     float64
# status                         object
# county_name                    object
# sample_code                    object
# sample_date            datetime64[ns]
# sample_depth                  float64
# sample_depth_units             object
# anl_data_type                  object
# parameter                      object
# fdr_result                    float64
# fdr_text_result                object
# fdr_date_result                object
# fdr_reporting_limit           float64
# uns_name                       object
# mth_name                       object
# fdr_footnote                   object
# dtype: object

# %%
field_df["year"] = field_df["sample_date"].dt.year

# %%
filtered_df = field_df[(field_df["year"] >= 2000) & (field_df["year"] <= 2025)]

# %%
filtered_df.shape
# Out:
# (365502, 23)

# %%
print(filtered_df["station_id"].nunique())
print(filtered_df["station_name"].nunique())
print(filtered_df["station_number"].nunique())
print(filtered_df["full_station_name"].nunique())
# Out:
# 2705
# 2701
# 2705
# 2658

# %%
filtered_df["county_name"].nunique()
# Out:
# 54

# %%
missing_ratio = filtered_df.isnull().sum()/filtered_df.shape[0]
high_missing_cols = missing_ratio[missing_ratio > 0.5].index.tolist()
len(high_missing_cols)
# Out:
# 4

# %%
filtered_df = filtered_df.drop(columns = high_missing_cols)
filtered_df.shape
# Out:
# (365502, 19)

# %%
filtered_df["station_type"].value_counts()
# Out:
# station_type
# Surface Water    348388
# Groundwater       16110
# Other              1004
# Name: count, dtype: int64

# %%
filtered_df = filtered_df.drop(columns = "status")

# %%
filtered_df["parameter"].nunique()
# Out:
# 58

# %%
filtered_df["parameter"].unique()
# Out:
# array(['DissolvedOxygen', 'Flow, channel', 'Secchi Depth',
#        'SpecificConductance', 'Turbidity', 'WaterTemperature', 'pH',
#        'Field Notes', 'Chlorophyll Volume', 'Water Depth at Station',
#        'Reference Point to Water Surface (RPTOWS)', 'Gauge Height',
#        'ElectricalConductance', 'Weather Observations', 'NorthLatitude',
#        'WestLongitude', 'AirTemperature', 'Percent Cloud Cover',
#        'Wind Direction', 'Wind Velocity', 'Wind Velocity and Direction',
#        '(Bottom) SpecificConductance', '(Bottom)Turbidity', '(Bottom)pH',
#        'Discharge', 'WaterColor (Description)',
#        'Chlorophyll Fluorescence', 'Microcystis aeruginosa',
#        '(Bottom) DissolvedOxygen', '(Bottom) WaterTemperature',
#        '(Bottom)Chlorophyll Fluorescence', 'All', 'Algae (Description)',
#        'Tide Time', 'Specific Gravity', 'Wind Velocity (Range)',
#        'Density', 'Turbidity (Description)', 'Foam (Description)', 'CROP',
#        'Irrigation Status', 'Field Status', 'Crop Height',
#        'Meter Reading', 'Flow, pipe', 'Crop Height (Range)',
#        'OutflowMeter Reading', 'InflowMeter Reading', 'Redox Potential',
#        '(Bottom)Water Depth at Station',
#        'SpecificConductance (EC w/time)', 'WaterTemperature (w/time)',
#        'pH (w/time)', 'Turbidity (w/time)', 'Odor', 'Odor (Description)',
#        'SoilRedox Potential', 'Carbon Dioxide'], dtype=object)

# %% [markdown]
# **Analysing samples taken by county to see if all counties should be included in dataset for training**

# %%
county_counts = filtered_df['county_name'].value_counts()

# Plotting with labels and title
ax = county_counts.plot(kind='bar', figsize=(15, 4))
ax.set_title('Distribution of Water Quality Samples by County', fontsize=14)
ax.set_xlabel('County Name', fontsize=12)
ax.set_ylabel('Number of Samples', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# The distribution of samples across 54 counties is highly imbalanced
#
# A few counties — San Joaquin, Contra Costa, Solano, Sacramento, Yolo — have very high sample counts (up to 60,000+).
#
# Most other counties have less than 5,000 samples, and several have only a few hundred.

# %% [markdown]
# To ensure data consistency and avoid overrepresentation bias, the WQI model was trained using data from the 15 counties with ≥3,000 observations, which account for over 80% of total field samples collected between 2000 and 2025.

# %%
# sample counts per county
county_counts = filtered_df['county_name'].value_counts()

# counties with at least 3000 samples
valid_counties = county_counts[county_counts >= 3000].index

filtered_top = filtered_df[filtered_df['county_name'].isin(valid_counties)]

# %%
len(valid_counties )
# Out:
# 21

# %%
valid_counts = county_counts[county_counts >= 3000]

# Plotting with labels and title
ax = valid_counts.plot(kind='bar', figsize=(10, 4))
ax.set_title('Selected Counties with ≥3000 Water Quality Samples', fontsize=14)
ax.set_xlabel('County Name', fontsize=12)
ax.set_ylabel('Number of Samples', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# After filtering 25 years of field data, 18 counties with over 3,000 observations each were selected to ensure consistency and balance.

# %%
filtered_top.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'county_name', 'sample_code',
#        'sample_date', 'sample_depth', 'sample_depth_units', 'parameter',
#        'fdr_result', 'fdr_reporting_limit', 'uns_name', 'mth_name', 'year'],
#       dtype='object')

# %%
filtered_top.shape
# Out:
# (334259, 18)

# %% [markdown]
# **Given a new set of field readings for a station, what is the likely water quality category?**

# %%
filtered_top.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'county_name', 'sample_code',
#        'sample_date', 'sample_depth', 'sample_depth_units', 'parameter',
#        'fdr_result', 'fdr_reporting_limit', 'uns_name', 'mth_name', 'year'],
#       dtype='object')

# %%
core_physicochemical = [
    'DissolvedOxygen',
    '(Bottom) DissolvedOxygen',
    'pH',
    '(Bottom)pH',
    'pH (w/time)',
    'WaterTemperature',
    '(Bottom) WaterTemperature',
    'WaterTemperature (w/time)',
    'Turbidity',
    '(Bottom)Turbidity',
    'Turbidity (w/time)',
    'Secchi Depth',
    'SpecificConductance',
    'ElectricalConductance',
    '(Bottom) SpecificConductance',
    'SpecificConductance (EC w/time)',
    'Chlorophyll Fluorescence',
    '(Bottom)Chlorophyll Fluorescence',
    'Chlorophyll Volume',
    'Carbon Dioxide',
    'Redox Potential',
    'SoilRedox Potential',
    'Flow, channel',
    'Discharge'
]

# %%
len(core_physicochemical)
# Out:
# 24

# %%
# env_influence = [
#     'AirTemperature',
#     'Gauge Height',
#     'Percent Cloud Cover',
#     'Wind Velocity',
#     'Wind Direction'
# ]

# %%
param_filtered = filtered_top.loc[filtered_top["parameter"].isin(core_physicochemical)].copy()

# %%
param_filtered.shape
# Out:
# (277166, 18)

# %%
param_filtered["sample_depth_units"].unique()
# Out:
# array(['Meters', 'Feet', 'inches'], dtype=object)

# %% [markdown]
# **Standardizing sample depth to meters**

# %%
param_filtered['sample_depth'] = pd.to_numeric(param_filtered['sample_depth'], errors='coerce')

# Standardize the unit names
param_filtered['sample_depth_units'] = param_filtered['sample_depth_units'].str.strip().str.lower()

# Conversion logic
def convert_to_meters(row):
    depth = row['sample_depth']
    unit = row['sample_depth_units']

    if pd.isna(depth):
        return np.nan
    if unit in ['meter', 'meters', 'm']:
        return depth
    elif unit in ['foot', 'feet', 'ft']:
        return depth * 0.3048
    elif unit in ['inch', 'inches', 'in']:
        return depth * 0.0254
    else:
        return np.nan  # unknown or missing unit

# Apply conversion
param_filtered['sample_depth_meter'] = param_filtered.apply(convert_to_meters, axis=1)

# %%
param_filtered["sample_depth_meter"].min(), param_filtered["sample_depth_meter"].max()
# Out:
# (-0.34999999, 504.0)

# %%
param_filtered[['sample_depth', 'sample_depth_units', 'sample_depth_meter']].tail()
# Out:
#          sample_depth sample_depth_units  sample_depth_meter
# 1210989           1.0             meters                 1.0
# 1210990           1.0             meters                 1.0
# 1210991           1.0             meters                 1.0
# 1210992           1.0             meters                 1.0
# 1210993           1.0             meters                 1.0

# %%
param_filtered = param_filtered.drop(columns=['sample_depth', 'sample_depth_units'])

# %%
param_filtered.shape
# Out:
# (277166, 17)

# %%
param_filtered
# Out:
#          station_id          station_name station_number  \
# 4010             12  H.O. Banks Headworks       KA000331
# 4011             12  H.O. Banks Headworks       KA000331
# 4012             12  H.O. Banks Headworks       KA000331
# 4013             12  H.O. Banks Headworks       KA000331
# 4014             12  H.O. Banks Headworks       KA000331
# ...             ...                   ...            ...
# 1210989       48146            DWSC North    A0X82491367
# 1210990       48146            DWSC North    A0X82491367
# 1210991       48146            DWSC North    A0X82491367
# 1210992       48146            DWSC North    A0X82491367
# 1210993       48146            DWSC North    A0X82491367
#
#                                      full_station_name   station_type  \
# 4010             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4011             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4012             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4013             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4014             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# ...                                                ...            ...
# 1210989  Sacramento Ship Channel North of Cache Slough  Surface Water
# 1210990  Sacramento Ship Channel North of Cache Slough  Surface Water
# 1210991  Sacramento Ship Channel North of Cache Slough  Surface Water
# 1210992  Sacramento Ship Channel North of Cache Slough  Surface Water
# 1210993  Sacramento Ship Channel North of Cache Slough  Surface Water
#
#          latitude  longitude county_name   sample_code         sample_date  \
# 4010     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4011     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4012     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4013     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4014     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# ...           ...        ...         ...           ...                 ...
# 1210989  38.41578  -121.6120        Yolo  ES0724B00032 2024-07-29 09:41:00
# 1210990  38.41578  -121.6120        Yolo  ES0824B00050 2024-08-12 10:51:00
# 1210991  38.41578  -121.6120        Yolo  ES0824B00050 2024-08-12 10:51:00
# 1210992  38.41578  -121.6120        Yolo  ES0824B00055 2024-08-26 08:44:00
# 1210993  38.41578  -121.6120        Yolo  ES0824B00055 2024-08-26 08:44:00
#
#                    parameter  fdr_result  fdr_reporting_limit     uns_name  \
# 4010         DissolvedOxygen         9.8                  0.2         mg/L
# 4011           Flow, channel      5650.0                  1.0          cfs
# 4012            Secchi Depth         0.9                  0.1       Meters
# 4013     SpecificConductance       420.0                  1.0  uS/cm@25 °C
# 4014               Turbidity         7.0                  0.1       N.T.U.
# ...                      ...         ...                  ...          ...
# 1210989  SpecificConductance       653.0                  NaN  uS/cm@25 °C
# 1210990   Chlorophyll Volume       250.0                  NaN           mL
# 1210991  SpecificConductance       578.0                  NaN  uS/cm@25 °C
# 1210992   Chlorophyll Volume       500.0                  NaN           mL
# 1210993  SpecificConductance       591.0                  NaN  uS/cm@25 °C
#
#                             mth_name  year  sample_depth_meter
# 4010               EPA 360.2 (Field)  2000                 1.0
# 4011                   Flow, Channel  2000                 1.0
# 4012                    Secchi Depth  2000                 1.0
# 4013               EPA 120.1 (Field)  2000                 1.0
# 4014               EPA 180.1 (Field)  2000                 1.0
# ...                              ...   ...                 ...
# 1210989            EPA 120.1 (Field)  2024                 1.0
# 1210990  Chlorophyll Volume Filtered  2024                 1.0
# 1210991            EPA 120.1 (Field)  2024                 1.0
# 1210992  Chlorophyll Volume Filtered  2024                 1.0
# 1210993            EPA 120.1 (Field)  2024                 1.0
#
# [277166 rows x 17 columns]

# %% [markdown]
# **Finding what are the units for each parameter**

# %%
param_filtered["parameter"].nunique()
# Out:
# 24

# %%
unit_summary = (
    param_filtered.groupby('parameter')['uns_name']
    .unique()
    .reset_index()
    .rename(columns={'uns_name': 'units_found'})
)

# Display first few results
print(unit_summary.head(25))
# Out:
#                            parameter                      units_found
# 0           (Bottom) DissolvedOxygen             [mg/L, % Saturation]
# 1       (Bottom) SpecificConductance     [uS/cm@25 °C, µmhos/cm@25°C]
# 2          (Bottom) WaterTemperature                             [°C]
# 3   (Bottom)Chlorophyll Fluorescence               [ug/L of Chl, RFU]
# 4                  (Bottom)Turbidity                 [N.T.U., F.N.U.]
# 5                         (Bottom)pH                       [pH Units]
# 6                     Carbon Dioxide                           [mg/L]
# 7           Chlorophyll Fluorescence               [RFU, ug/L of Chl]
# 8                 Chlorophyll Volume                             [mL]
# 9                          Discharge                            [cfs]
# 10                   DissolvedOxygen       [mg/L, % Saturation, %,  ]
# 11             ElectricalConductance          [ , uS/cm, uS/cm@25 °C]
# 12                     Flow, channel                   [cfs, Gallons]
# 13                   Redox Potential                             [mV]
# 14                      Secchi Depth   [Meters, Feet, Centimeters,  ]
# 15               SoilRedox Potential                             [mV]
# 16               SpecificConductance  [uS/cm@25 °C, µmhos/cm@25°C,  ]
# 17   SpecificConductance (EC w/time)                    [uS/cm@25 °C]
# 18                         Turbidity              [N.T.U., F.N.U.,  ]
# 19                Turbidity (w/time)                         [N.T.U.]
# 20                  WaterTemperature                      [°C,  , °F]
# 21         WaterTemperature (w/time)                             [°C]
# 22                                pH                    [pH Units,  ]
# 23                       pH (w/time)                       [pH Units]

# %% [markdown]
# # Standardizing the units for each parameter

# %%
import pandas as pd
import numpy as np
import re

# ---------- Clean unit strings ----------
def clean_unit(u):
    if pd.isna(u):
        return ''
    u = (
        str(u)
        .strip()
        .lower()
        .replace('°c', 'c')
        .replace('@25 °c', '')
        .replace('@25°c', '')
        .replace('µmhos/cm', 'us/cm')
        .replace('n.t.u.', 'ntu')
        .replace('f.n.u.', 'ntu')
        .replace('ug/l of chl', 'ug/l')
    )
    return u

# Apply to dataframe
param_filtered['uns_name'] = param_filtered['uns_name'].apply(clean_unit)

# ----------  Define conversion logic ----------
def convert_value(val, param, unit):
    """Convert a single numeric value to standardized units."""
    if pd.isna(val):
        return np.nan

    p = str(param).lower().strip()
    u = str(unit).lower().strip()

    # ---- Dissolved Oxygen (% → mg/L) ----
    if 'dissolvedoxygen' in p and '%' in u:
        return (val * 14.6) / 100  # approximate saturation at 25°C, 1 atm

    # ---- Conductance (mS/cm → µS/cm) ----
    elif 'conductance' in p and ('ms/cm' in u):
        return val * 1000

    # ---- Temperature (°F → °C) ----
    elif 'temperature' in p and u in ['f', '°f']:
        return (val - 32) * 5 / 9

    # ---- Secchi Depth (Feet → m; Centimeters → m) ----
    elif 'secchi' in p and 'feet' in u:
        return val * 0.3048
    elif 'secchi' in p and 'centimeter' in u:
        return val * 0.01

    # ---- Flow / Discharge (cfs → m³/s; gallons → m³/s if per sec) ----
    elif (('flow' in p) or ('discharge' in p)) and 'cfs' in u:
        return val * 0.0283168
    elif (('flow' in p) or ('discharge' in p)) and 'gallon' in u:
        return val * 3.78541e-3  # assuming gallons per second

    # ---- Turbidity (NTU/FNU → NTU) ----
    elif 'turbidity' in p and ('ntu' in u or 'fnu' in u):
        return val  # equivalent

    # ---- pH ----
    elif re.search(r'\bph\b', p):
        return val  # already standardized

    # ---- Chlorophyll (RFU → leave unchanged) ----
    elif 'chlorophyll' in p and 'rfu' in u:
        return val  # qualitative unit, keep as-is

    # ---- Everything else already in correct unit ----
    else:
        return val


# ---------- Apply to both numeric columns ----------
def standardize_row(row):
    return pd.Series({
        'fdr_result_std': convert_value(row['fdr_result'], row['parameter'], row['uns_name']),
        'fdr_reporting_limit_std': convert_value(row['fdr_reporting_limit'], row['parameter'], row['uns_name'])
    })

param_filtered[['fdr_result_std', 'fdr_reporting_limit_std']] = param_filtered.apply(standardize_row, axis=1)

# ---------- Assign standardized unit label ----------
def assign_std_unit(param):
    p = param.lower().strip()
    if 'oxygen' in p:
        return 'mg/L'
    elif re.fullmatch(r'ph.*', p) or p.startswith('ph '):
        return 'pH units'
    elif 'temperature' in p:
        return '°C'
    elif 'conductance' in p:
        return 'µS/cm'
    elif 'turbidity' in p:
        return 'NTU'
    elif 'secchi' in p:
        return 'm'
    elif 'flow' in p or 'discharge' in p:
        return 'm³/s'
    elif 'redox' in p:
        return 'mV'
    elif 'chlorophyll' in p:
        return 'µg/L'
    elif 'carbon dioxide' in p:
        return 'mg/L'
    else:
        return None

param_filtered['std_unit'] = param_filtered['parameter'].apply(assign_std_unit)

# %%
param_filtered[['parameter', 'uns_name', 'fdr_result', 'fdr_result_std', 'fdr_reporting_limit', 'fdr_reporting_limit_std', 'std_unit']].sample(5)
# Out:
#                          parameter      uns_name  fdr_result  fdr_result_std  \
# 654939   (Bottom) WaterTemperature             c       14.98         14.9800
# 465297                          pH      ph units        7.50          7.5000
# 568892                   Turbidity           ntu       17.60         17.6000
# 1064931           WaterTemperature             c       11.90         11.9000
# 658482             DissolvedOxygen  % saturation       94.20         13.7532
#
#          fdr_reporting_limit  fdr_reporting_limit_std  std_unit
# 654939                   0.1                      0.1        °C
# 465297                   0.1                      0.1  pH units
# 568892                   0.1                      0.1       NTU
# 1064931                  0.1                      0.1        °C
# 658482                   NaN                      NaN      mg/L

# %%
# ---------- Replace old columns if verified ----------
param_filtered = param_filtered.drop(columns=['fdr_result', 'fdr_reporting_limit'])
param_filtered = param_filtered.rename(columns={
    'fdr_result_std': 'fdr_result',
    'fdr_reporting_limit_std': 'fdr_reporting_limit'
})

# %%
# Now only one unit for each parameter
unit_summary = (
    param_filtered.groupby('parameter')['std_unit']
    .unique()
    .reset_index()
    .rename(columns={'std_unit': 'units_found'})
)

# Display first few results
print(unit_summary.head(25))
# Out:
#                            parameter units_found
# 0           (Bottom) DissolvedOxygen      [mg/L]
# 1       (Bottom) SpecificConductance     [µS/cm]
# 2          (Bottom) WaterTemperature        [°C]
# 3   (Bottom)Chlorophyll Fluorescence      [µg/L]
# 4                  (Bottom)Turbidity       [NTU]
# 5                         (Bottom)pH      [None]
# 6                     Carbon Dioxide      [mg/L]
# 7           Chlorophyll Fluorescence      [µg/L]
# 8                 Chlorophyll Volume      [µg/L]
# 9                          Discharge      [m³/s]
# 10                   DissolvedOxygen      [mg/L]
# 11             ElectricalConductance     [µS/cm]
# 12                     Flow, channel      [m³/s]
# 13                   Redox Potential        [mV]
# 14                      Secchi Depth         [m]
# 15               SoilRedox Potential        [mV]
# 16               SpecificConductance     [µS/cm]
# 17   SpecificConductance (EC w/time)     [µS/cm]
# 18                         Turbidity       [NTU]
# 19                Turbidity (w/time)       [NTU]
# 20                  WaterTemperature        [°C]
# 21         WaterTemperature (w/time)        [°C]
# 22                                pH  [pH units]
# 23                       pH (w/time)  [pH units]

# %%
param_filtered.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'county_name', 'sample_code',
#        'sample_date', 'parameter', 'uns_name', 'mth_name', 'year',
#        'sample_depth_meter', 'fdr_result', 'fdr_reporting_limit', 'std_unit'],
#       dtype='object')

# %%
param_filtered = param_filtered.drop(columns = ["uns_name"])

# %%
param_filtered.shape
# Out:
# (277166, 17)

# %%
cleaned_data = param_filtered.copy()

# %%
cleaned_data['parameter_unit'] = (
    cleaned_data['parameter'].astype(str).str.strip() + "_" +
    cleaned_data['std_unit'].astype(str).str.strip()
)

# %%
cleaned_data.shape
# Out:
# (277166, 18)

# %%
cleaned_data.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'county_name', 'sample_code',
#        'sample_date', 'parameter', 'mth_name', 'year', 'sample_depth_meter',
#        'fdr_result', 'fdr_reporting_limit', 'std_unit', 'parameter_unit'],
#       dtype='object')

# %%
cleaned_data = cleaned_data.drop(columns = ["parameter", "std_unit"])

# %%
cleaned_data.shape
# Out:
# (277166, 16)

# %%
cleaned_data["mth_name"].nunique()
# Out:
# 19

# %%
cleaned_data["mth_name"].unique()
# Out:
# array(['EPA 360.2 (Field)', 'Flow, Channel', 'Secchi Depth',
#        'EPA 120.1 (Field)', 'EPA 180.1 (Field)', 'EPA 170.1 (Field)',
#        'EPA 150.1 (Field)', 'EPA 360.1 (Field)',
#        'ASTM Method D888-09-C (Field)', 'Chlorophyll Volume Filtered',
#        'Std Method 2510-B (Field)', 'Turbidity, Sonde',
#        'SM 4500-H B-2000 (Field)', 'Fluorescence, Blue Lamp',
#        'Fluorescence, Sonde', 'Std Method 2580 (Water)',
#        'Turbidity, Signal Avg, Field', 'Std Method 2580 (Soil/Sed)',
#        '(Field) CO2'], dtype=object)

# %% [markdown]
# The column mth_name (Method Name) typically records the analytical or field method used to measure each parameter.
#
# The differences in measurement method are already reflected in the numeric results (fdr_result).
#
# Models learn from the standardized parameter values, not how they were measured.
#
# Including mth_name (a categorical feature with dozens of rare values) adds noise and doesn’t improve predictive performance.

# %%
# Dropping mth_name as its not required for modelling

cleaned_data = cleaned_data.drop(columns=['mth_name'])

# %%
cleaned_data.shape
# Out:
# (277166, 15)

# %%
cleaned_data
# Out:
#          station_id          station_name station_number  \
# 4010             12  H.O. Banks Headworks       KA000331
# 4011             12  H.O. Banks Headworks       KA000331
# 4012             12  H.O. Banks Headworks       KA000331
# 4013             12  H.O. Banks Headworks       KA000331
# 4014             12  H.O. Banks Headworks       KA000331
# ...             ...                   ...            ...
# 1210989       48146            DWSC North    A0X82491367
# 1210990       48146            DWSC North    A0X82491367
# 1210991       48146            DWSC North    A0X82491367
# 1210992       48146            DWSC North    A0X82491367
# 1210993       48146            DWSC North    A0X82491367
#
#                                      full_station_name   station_type  \
# 4010             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4011             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4012             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4013             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4014             Delta P.P. Headworks at H.O. Banks PP  Surface Water
# ...                                                ...            ...
# 1210989  Sacramento Ship Channel North of Cache Slough  Surface Water
# 1210990  Sacramento Ship Channel North of Cache Slough  Surface Water
# 1210991  Sacramento Ship Channel North of Cache Slough  Surface Water
# 1210992  Sacramento Ship Channel North of Cache Slough  Surface Water
# 1210993  Sacramento Ship Channel North of Cache Slough  Surface Water
#
#          latitude  longitude county_name   sample_code         sample_date  \
# 4010     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4011     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4012     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4013     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4014     37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# ...           ...        ...         ...           ...                 ...
# 1210989  38.41578  -121.6120        Yolo  ES0724B00032 2024-07-29 09:41:00
# 1210990  38.41578  -121.6120        Yolo  ES0824B00050 2024-08-12 10:51:00
# 1210991  38.41578  -121.6120        Yolo  ES0824B00050 2024-08-12 10:51:00
# 1210992  38.41578  -121.6120        Yolo  ES0824B00055 2024-08-26 08:44:00
# 1210993  38.41578  -121.6120        Yolo  ES0824B00055 2024-08-26 08:44:00
#
#          year  sample_depth_meter  fdr_result  fdr_reporting_limit  \
# 4010     2000                 1.0     9.80000             0.200000
# 4011     2000                 1.0   159.98992             0.028317
# 4012     2000                 1.0     0.90000             0.100000
# 4013     2000                 1.0   420.00000             1.000000
# 4014     2000                 1.0     7.00000             0.100000
# ...       ...                 ...         ...                  ...
# 1210989  2024                 1.0   653.00000                  NaN
# 1210990  2024                 1.0   250.00000                  NaN
# 1210991  2024                 1.0   578.00000                  NaN
# 1210992  2024                 1.0   500.00000                  NaN
# 1210993  2024                 1.0   591.00000                  NaN
#
#                     parameter_unit
# 4010          DissolvedOxygen_mg/L
# 4011            Flow, channel_m³/s
# 4012                Secchi Depth_m
# 4013     SpecificConductance_µS/cm
# 4014                 Turbidity_NTU
# ...                            ...
# 1210989  SpecificConductance_µS/cm
# 1210990    Chlorophyll Volume_µg/L
# 1210991  SpecificConductance_µS/cm
# 1210992    Chlorophyll Volume_µg/L
# 1210993  SpecificConductance_µS/cm
#
# [277166 rows x 15 columns]

# %%
cleaned_data.isnull().sum()
# Out:
# station_id                 0
# station_name               0
# station_number             0
# full_station_name          0
# station_type               0
# latitude                7181
# longitude               7181
# county_name                0
# sample_code                0
# sample_date                0
# year                       0
# sample_depth_meter      2203
# fdr_result               315
# fdr_reporting_limit    28860
# parameter_unit             0
# dtype: int64

# %%
print(cleaned_data["station_id"].nunique())
print(cleaned_data["station_name"].nunique())
print(cleaned_data["station_number"].nunique())
print(cleaned_data["full_station_name"].nunique())
print(cleaned_data["latitude"].nunique())
# Out:
# 1889
# 1887
# 1889
# 1846
# 1473

# %%
cleaned_data.loc[cleaned_data["latitude"].isnull()]
# Out:
#          station_id       station_name station_number  \
# 48155         45487   LindoC nr EastRR       A0032010
# 48156         45487   LindoC nr EastRR       A0032010
# 48157         45487   LindoC nr EastRR       A0032010
# 48158         45487   LindoC nr EastRR       A0032010
# 48162         45488  LindoC @ MissionR       A0032020
# ...             ...                ...            ...
# 1138331       45535    Deer bl ChildsM       A4317600
# 1138333       45535    Deer bl ChildsM       A4317600
# 1138334       45535    Deer bl ChildsM       A4317600
# 1138335       45535    Deer bl ChildsM       A4317600
# 1138336       45535    Deer bl ChildsM       A4317600
#
#                              full_station_name   station_type  latitude  \
# 48155    Lindo Channel nr East Ave & RR tracks  Surface Water       NaN
# 48156    Lindo Channel nr East Ave & RR tracks  Surface Water       NaN
# 48157    Lindo Channel nr East Ave & RR tracks  Surface Water       NaN
# 48158    Lindo Channel nr East Ave & RR tracks  Surface Water       NaN
# 48162         Lindo Channel @ Mission Ranch Rd  Surface Water       NaN
# ...                                        ...            ...       ...
# 1138331                Deer C bl Childs Meadow  Surface Water       NaN
# 1138333                Deer C bl Childs Meadow  Surface Water       NaN
# 1138334                Deer C bl Childs Meadow  Surface Water       NaN
# 1138335                Deer C bl Childs Meadow  Surface Water       NaN
# 1138336                Deer C bl Childs Meadow  Surface Water       NaN
#
#          longitude county_name  sample_code         sample_date  year  \
# 48155          NaN       Butte  NA0100B2387 2000-01-11 12:00:00  2000
# 48156          NaN       Butte  NA0100B2387 2000-01-11 12:00:00  2000
# 48157          NaN       Butte  NA0100B2387 2000-01-11 12:00:00  2000
# 48158          NaN       Butte  NA0100B2387 2000-01-11 12:00:00  2000
# 48162          NaN       Butte  NA0100B2386 2000-01-11 12:00:00  2000
# ...            ...         ...          ...                 ...   ...
# 1138331        NaN      Tehama  NA0200B2551 2000-02-14 10:30:00  2000
# 1138333        NaN      Tehama  NA0400B0023 2000-04-17 09:15:00  2000
# 1138334        NaN      Tehama  NA0400B0023 2000-04-17 09:15:00  2000
# 1138335        NaN      Tehama  NA0400B0023 2000-04-17 09:15:00  2000
# 1138336        NaN      Tehama  NA0400B0023 2000-04-17 09:15:00  2000
#
#          sample_depth_meter  fdr_result  fdr_reporting_limit  \
# 48155                  0.15         8.5                  0.2
# 48156                  0.15        79.0                  1.0
# 48157                  0.15        11.8                  0.1
# 48158                  0.15         6.8                  0.1
# 48162                  0.15         9.2                  0.2
# ...                     ...         ...                  ...
# 1138331                0.15         7.0                  0.1
# 1138333                0.15        10.2                  0.2
# 1138334                0.15        46.0                  1.0
# 1138335                0.15         5.7                  0.1
# 1138336                0.15         7.3                  0.1
#
#                     parameter_unit
# 48155         DissolvedOxygen_mg/L
# 48156    SpecificConductance_µS/cm
# 48157          WaterTemperature_°C
# 48158                  pH_pH units
# 48162         DissolvedOxygen_mg/L
# ...                            ...
# 1138331                pH_pH units
# 1138333       DissolvedOxygen_mg/L
# 1138334  SpecificConductance_µS/cm
# 1138335        WaterTemperature_°C
# 1138336                pH_pH units
#
# [7181 rows x 15 columns]

# %% [markdown]
# ### Handling Missing values

# %%
# Dropping rows with missing value in fdr_result

cleaned_data = cleaned_data.loc[~cleaned_data["fdr_result"].isnull()]

# %%
missing_coords = cleaned_data[cleaned_data['latitude'].isna() | cleaned_data['longitude'].isna()]
print(missing_coords['station_id'].nunique(), "stations missing coordinates")
# Out:
# 26 stations missing coordinates

# %%
# using mean of other stations in county to fill missing values
county_coords = (
    cleaned_data.groupby('county_name')[['latitude', 'longitude']]
    .mean()
    .reset_index()
)

cleaned_data = cleaned_data.merge(county_coords, on='county_name', how='left', suffixes=('', '_county'))
cleaned_data['latitude'] = cleaned_data['latitude'].fillna(cleaned_data['latitude_county'])
cleaned_data['longitude'] = cleaned_data['longitude'].fillna(cleaned_data['longitude_county'])
cleaned_data = cleaned_data.drop(columns=['latitude_county', 'longitude_county'])

# %%
cleaned_data["parameter_unit"].unique()
# Out:
# array(['DissolvedOxygen_mg/L', 'Flow, channel_m³/s', 'Secchi Depth_m',
#        'SpecificConductance_µS/cm', 'Turbidity_NTU',
#        'WaterTemperature_°C', 'pH_pH units', 'Chlorophyll Volume_µg/L',
#        'ElectricalConductance_µS/cm',
#        '(Bottom) SpecificConductance_µS/cm', '(Bottom)Turbidity_NTU',
#        '(Bottom)pH_None', 'Discharge_m³/s',
#        'Chlorophyll Fluorescence_µg/L', '(Bottom) DissolvedOxygen_mg/L',
#        '(Bottom) WaterTemperature_°C',
#        '(Bottom)Chlorophyll Fluorescence_µg/L', 'Redox Potential_mV',
#        'SpecificConductance (EC w/time)_µS/cm',
#        'WaterTemperature (w/time)_°C', 'pH (w/time)_pH units',
#        'Turbidity (w/time)_NTU', 'SoilRedox Potential_mV',
#        'Carbon Dioxide_mg/L'], dtype=object)

# %%
cleaned_data.loc[cleaned_data["parameter_unit"] == "DissolvedOxygen_mg/L", "fdr_reporting_limit"]
# Out:
# 0         0.2
# 7         0.2
# 14        0.2
# 21        0.2
# 28        0.2
#          ...
# 276762    NaN
# 276768    NaN
# 276774    NaN
# 276780    NaN
# 276786    NaN
# Name: fdr_reporting_limit, Length: 44651, dtype: float64

# %%
county_param_fdr_limits = (
    cleaned_data.groupby(['county_name', 'parameter_unit'])['fdr_reporting_limit']
    .median()
    .reset_index()
)

# %%
county_param_fdr_limits.loc[county_param_fdr_limits["fdr_reporting_limit"].isnull()]
# Out:
#     county_name               parameter_unit  fdr_reporting_limit
# 14        Butte  ElectricalConductance_µS/cm                  NaN
# 70       Merced      Chlorophyll Volume_µg/L                  NaN
# 79       Placer      Chlorophyll Volume_µg/L                  NaN
# 192      Tehama              (Bottom)pH_None                  NaN

# %%
# Use county mean reporting limits for parameters
cleaned_data = cleaned_data.merge(county_param_fdr_limits, on = ["county_name", "parameter_unit"], suffixes=('', '_county'))
cleaned_data['fdr_reporting_limit'] = cleaned_data['fdr_reporting_limit'].fillna(cleaned_data['fdr_reporting_limit_county'])
cleaned_data = cleaned_data.drop(columns=['fdr_reporting_limit_county'])

# %%
# Using global parameter median value to fill remaining fdr limits missing values

param_medians_global = (
    cleaned_data.groupby('parameter_unit')['fdr_reporting_limit']
    .median()
    .to_dict()
)

cleaned_data['fdr_reporting_limit'] = cleaned_data.apply(
    lambda x: param_medians_global.get(x['parameter_unit'], np.nan)
    if pd.isna(x['fdr_reporting_limit']) else x['fdr_reporting_limit'],
    axis=1
)

# %%
cleaned_data["station_type"].unique()
# Out:
# array(['Surface Water', 'Groundwater', 'Other'], dtype=object)

# %%
cleaned_data.loc[cleaned_data["station_type"] == "Surface Water", "sample_depth_meter"].min(), cleaned_data.loc[cleaned_data["station_type"] == "Surface Water", "sample_depth_meter"].max()
# Out:
# (-0.34999999, 150.0)

# %%
cleaned_data.loc[cleaned_data["station_type"] == "Groundwater", "sample_depth_meter"].min(), cleaned_data.loc[cleaned_data["station_type"] == "Groundwater", "sample_depth_meter"].max()
# Out:
# (0.0, 504.0)

# %%
cleaned_data.loc[cleaned_data["station_type"] == "Other", "sample_depth_meter"].min(), cleaned_data.loc[cleaned_data["station_type"] == "Other", "sample_depth_meter"].max()
# Out:
# (0.0, 1.0)

# %%
## Crorrecting sample depth values and imputting missing values

# ---- Surface Water corrections ----
mask_surface = cleaned_data['station_type'].str.lower().str.contains('surface')
cleaned_data.loc[mask_surface & (cleaned_data['sample_depth_meter'] < 0), 'sample_depth_meter'] = 0
cleaned_data.loc[mask_surface & (cleaned_data['sample_depth_meter'] > 50), 'sample_depth_meter'] = np.nan

# ---- Groundwater corrections ----
mask_ground = cleaned_data['station_type'].str.lower().str.contains('ground')
cleaned_data.loc[mask_ground & (cleaned_data['sample_depth_meter'] < 0), 'sample_depth_meter'] = 0
cleaned_data.loc[mask_ground & (cleaned_data['sample_depth_meter'] > 500), 'sample_depth_meter'] = np.nan

# ---- Other corrections ----
mask_other = cleaned_data['station_type'].str.lower().str.contains('other')
cleaned_data.loc[mask_other & (cleaned_data['sample_depth_meter'] < 0), 'sample_depth_meter'] = 0
# cap at 1 m just in case of noise
cleaned_data.loc[mask_other & (cleaned_data['sample_depth_meter'] > 1), 'sample_depth_meter'] = np.nan

# ---- Re-impute missing depths after capping ----
# Fill by station median
cleaned_data['sample_depth_meter'] = cleaned_data.groupby('station_id')['sample_depth_meter']\
    .transform(lambda x: x.fillna(x.median()))

# Fill by station type median
type_medians = cleaned_data.groupby('station_type')['sample_depth_meter'].median().to_dict()
cleaned_data['sample_depth_meter'] = cleaned_data.apply(
    lambda x: type_medians.get(x['station_type'], np.nan)
    if pd.isna(x['sample_depth_meter']) else x['sample_depth_meter'],
    axis=1
)

# Fill remaining with 0 (surface-level default)
cleaned_data['sample_depth_meter'] = cleaned_data['sample_depth_meter'].fillna(0)

# ---- Verify final ranges ----
print(cleaned_data.groupby('station_type')['sample_depth_meter'].agg(['min', 'max', 'median', 'count']))
# Out:
#                min    max  median   count
# station_type
# Groundwater    0.0  500.0  1.0000   10472
# Other          0.0    1.0  1.0000     959
# Surface Water  0.0   49.0  0.9144  265420

# %%
cleaned_data.isnull().sum()
# Out:
# station_id             0
# station_name           0
# station_number         0
# full_station_name      0
# station_type           0
# latitude               0
# longitude              0
# county_name            0
# sample_code            0
# sample_date            0
# year                   0
# sample_depth_meter     0
# fdr_result             0
# fdr_reporting_limit    0
# parameter_unit         0
# dtype: int64

# %% [markdown]
# ### Checking if all the parameters are in valid range

# %%
cleaned_data["parameter_unit"].unique()
# Out:
# array(['DissolvedOxygen_mg/L', 'Flow, channel_m³/s', 'Secchi Depth_m',
#        'SpecificConductance_µS/cm', 'Turbidity_NTU',
#        'WaterTemperature_°C', 'pH_pH units', 'Chlorophyll Volume_µg/L',
#        'ElectricalConductance_µS/cm',
#        '(Bottom) SpecificConductance_µS/cm', '(Bottom)Turbidity_NTU',
#        '(Bottom)pH_None', 'Discharge_m³/s',
#        'Chlorophyll Fluorescence_µg/L', '(Bottom) DissolvedOxygen_mg/L',
#        '(Bottom) WaterTemperature_°C',
#        '(Bottom)Chlorophyll Fluorescence_µg/L', 'Redox Potential_mV',
#        'SpecificConductance (EC w/time)_µS/cm',
#        'WaterTemperature (w/time)_°C', 'pH (w/time)_pH units',
#        'Turbidity (w/time)_NTU', 'SoilRedox Potential_mV',
#        'Carbon Dioxide_mg/L'], dtype=object)

# %%
valid_ranges = {
    'DissolvedOxygen_mg/L': (0, 20),
    '(Bottom) DissolvedOxygen_mg/L': (0, 20),
    'Flow, channel_m³/s': (0, 10000),
    'Discharge_m³/s': (0, 10000),
    'Secchi Depth_m': (0, 50),
    'Turbidity_NTU': (0, 1000),
    '(Bottom)Turbidity_NTU': (0, 1000),
    'Turbidity (w/time)_NTU': (0, 1000),
    'SpecificConductance_µS/cm': (0, 50000),
    'ElectricalConductance_µS/cm': (0, 50000),
    '(Bottom) SpecificConductance_µS/cm': (0, 50000),
    'SpecificConductance (EC w/time)_µS/cm': (0, 50000),
    'WaterTemperature_°C': (-2, 50),
    '(Bottom) WaterTemperature_°C': (-2, 50),
    'WaterTemperature (w/time)_°C': (-2, 50),
    'pH_pH units': (0, 14),
    '(Bottom)pH_None': (0, 14),
    'pH (w/time)_pH units': (0, 14),
    'Chlorophyll Volume_µg/L': (0, 1000),
    'Chlorophyll Fluorescence_µg/L': (0, 1000),
    '(Bottom)Chlorophyll Fluorescence_µg/L': (0, 1000),
    'Redox Potential_mV': (-500, 1000),
    'SoilRedox Potential_mV': (-500, 1000),
    'Carbon Dioxide_mg/L': (0, 200)
}

# %%
def flag_parameter_values(df, param_col='parameter_unit', val_col='fdr_result'):
    """
    Flags parameter values as valid, missing, or out_of_range based on predefined valid_ranges.
    """
    def check_value(param, val):
        if pd.isna(val):
            return 'missing'
        if param not in valid_ranges:
            return 'unknown_param'
        low, high = valid_ranges[param]
        if val < low or val > high:
            return 'out_of_range'
        return 'valid'

    df['value_flag'] = df.apply(lambda x: check_value(x[param_col], x[val_col]), axis=1)
    return df

# Apply to your dataset
cleaned_data = flag_parameter_values(cleaned_data)

# %%
print(cleaned_data['value_flag'].value_counts())

# Inspect specific out-of-range examples
invalids = cleaned_data[cleaned_data['value_flag'] == 'out_of_range']
print(invalids[['parameter_unit', 'fdr_result']].head(10))
# Out:
# value_flag
# valid           276555
# out_of_range       296
# Name: count, dtype: int64
#             parameter_unit  fdr_result
# 358   DissolvedOxygen_mg/L  836.000000
# 764            pH_pH units   16.600000
# 7066           pH_pH units   24.900000
# 8160  DissolvedOxygen_mg/L   76.000000
# 8572           pH_pH units   70.200000
# 8722   WaterTemperature_°C   -4.222222
# 9512   WaterTemperature_°C  -13.111111
# 9565   WaterTemperature_°C   -7.333333
# 9576   WaterTemperature_°C   -2.833333
# 9588   WaterTemperature_°C  -12.333333

# %% [markdown]
# ### Handling the outlier values

# %%
summary_before = cleaned_data['value_flag'].value_counts()
print("\nBefore cleaning:")
print(summary_before)

outlier_count = cleaned_data[cleaned_data['value_flag'] == 'out_of_range'].shape[0]

# Set invalid results to NaN
cleaned_data.loc[cleaned_data['value_flag'] == 'out_of_range', 'fdr_result'] = np.nan

# Drop flag column (optional)
cleaned_data = cleaned_data.drop(columns=['value_flag'])

print(f"\nReplaced {outlier_count} out-of-range values with NaN.")


def check_remaining_outliers(df):
    issues = []
    for param, (low, high) in valid_ranges.items():
        mask = df.query("parameter_unit == @param and (fdr_result < @low or fdr_result > @high)")
        if not mask.empty:
            issues.append((param, len(mask)))
    if issues:
        print("\n Remaining outliers detected:")
        for p, c in issues:
            print(f" - {p}: {c} values still out of range")
    else:
        print("\n All parameter values fall within valid environmental ranges.")

check_remaining_outliers(cleaned_data)


param_summary = (
    cleaned_data.groupby('parameter_unit')['fdr_result']
    .agg(['count', 'min', 'max', 'median'])
    .sort_values('count', ascending=False)
)
print("\nSummary of cleaned parameter values:")
print(param_summary.head(10))
# Out:
# Before cleaning:
# value_flag
# valid           276555
# out_of_range       296
# Name: count, dtype: int64
#
# Replaced 296 out-of-range values with NaN.
#
#  All parameter values fall within valid environmental ranges.
#
# Summary of cleaned parameter values:
#                                        count   min         max  median
# parameter_unit
# SpecificConductance_µS/cm              52420  0.00  48600.0000  374.85
# WaterTemperature_°C                    50779 -0.10     50.0000   17.20
# pH_pH units                            46299  0.00     14.0000    7.71
# DissolvedOxygen_mg/L                   44526  0.00     20.0000    8.85
# Turbidity_NTU                          37278  0.00   1000.0000    7.80
# Secchi Depth_m                         11458  0.00     23.4000    0.80
# Chlorophyll Fluorescence_µg/L          10580  0.00    245.0000    2.20
# (Bottom) DissolvedOxygen_mg/L           3923  5.62     18.9946    9.79
# (Bottom)Chlorophyll Fluorescence_µg/L   3900  0.03     25.7300    1.70
# Chlorophyll Volume_µg/L                 2540  0.00    550.0000  500.00

# %%
cleaned_data.isnull().sum()
# Out:
# station_id               0
# station_name             0
# station_number           0
# full_station_name        0
# station_type             0
# latitude                 0
# longitude                0
# county_name              0
# sample_code              0
# sample_date              0
# year                     0
# sample_depth_meter       0
# fdr_result             296
# fdr_reporting_limit      0
# parameter_unit           0
# dtype: int64

# %%
cleaned_data
# Out:
#         station_id          station_name station_number  \
# 0               12  H.O. Banks Headworks       KA000331
# 1               12  H.O. Banks Headworks       KA000331
# 2               12  H.O. Banks Headworks       KA000331
# 3               12  H.O. Banks Headworks       KA000331
# 4               12  H.O. Banks Headworks       KA000331
# ...            ...                   ...            ...
# 276846       48146            DWSC North    A0X82491367
# 276847       48146            DWSC North    A0X82491367
# 276848       48146            DWSC North    A0X82491367
# 276849       48146            DWSC North    A0X82491367
# 276850       48146            DWSC North    A0X82491367
#
#                                     full_station_name   station_type  \
# 0               Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 1               Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 2               Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 3               Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4               Delta P.P. Headworks at H.O. Banks PP  Surface Water
# ...                                               ...            ...
# 276846  Sacramento Ship Channel North of Cache Slough  Surface Water
# 276847  Sacramento Ship Channel North of Cache Slough  Surface Water
# 276848  Sacramento Ship Channel North of Cache Slough  Surface Water
# 276849  Sacramento Ship Channel North of Cache Slough  Surface Water
# 276850  Sacramento Ship Channel North of Cache Slough  Surface Water
#
#         latitude  longitude county_name   sample_code         sample_date  \
# 0       37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 1       37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 2       37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 3       37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# 4       37.80190  -121.6203     Alameda   DA0100B0055 2000-01-19 08:20:00
# ...          ...        ...         ...           ...                 ...
# 276846  38.41578  -121.6120        Yolo  ES0724B00032 2024-07-29 09:41:00
# 276847  38.41578  -121.6120        Yolo  ES0824B00050 2024-08-12 10:51:00
# 276848  38.41578  -121.6120        Yolo  ES0824B00050 2024-08-12 10:51:00
# 276849  38.41578  -121.6120        Yolo  ES0824B00055 2024-08-26 08:44:00
# 276850  38.41578  -121.6120        Yolo  ES0824B00055 2024-08-26 08:44:00
#
#         year  sample_depth_meter  fdr_result  fdr_reporting_limit  \
# 0       2000                 1.0     9.80000             0.200000
# 1       2000                 1.0   159.98992             0.028317
# 2       2000                 1.0     0.90000             0.100000
# 3       2000                 1.0   420.00000             1.000000
# 4       2000                 1.0     7.00000             0.100000
# ...      ...                 ...         ...                  ...
# 276846  2024                 1.0   653.00000             1.000000
# 276847  2024                 1.0   250.00000             1.000000
# 276848  2024                 1.0   578.00000             1.000000
# 276849  2024                 1.0   500.00000             1.000000
# 276850  2024                 1.0   591.00000             1.000000
#
#                    parameter_unit
# 0            DissolvedOxygen_mg/L
# 1              Flow, channel_m³/s
# 2                  Secchi Depth_m
# 3       SpecificConductance_µS/cm
# 4                   Turbidity_NTU
# ...                           ...
# 276846  SpecificConductance_µS/cm
# 276847    Chlorophyll Volume_µg/L
# 276848  SpecificConductance_µS/cm
# 276849    Chlorophyll Volume_µg/L
# 276850  SpecificConductance_µS/cm
#
# [276851 rows x 15 columns]

# %%
# Creating a reference dataset to store limts

reference_dataset = cleaned_data[['station_id', 'parameter_unit', 'fdr_reporting_limit']].copy()

# %% [markdown]
# # Pivoting the table

# %%
# Pivot the data so each parameter becomes a column
pivoted = (
    cleaned_data
    .pivot_table(
        index=[
            'station_id', 'station_name', 'station_number', 'full_station_name',
            'station_type', 'latitude', 'longitude', 'county_name',
            'sample_code', 'sample_date', 'year', 'sample_depth_meter'
        ],
        columns='parameter_unit',
        values='fdr_result',
        aggfunc='mean'  # if duplicates exist, take the mean
    )
    .reset_index()
)

# Flatten the multi-index column headers
pivoted.columns.name = None
pivoted.columns = [str(c) for c in pivoted.columns]

print(f"Pivoted dataset shape: {pivoted.shape}")
pivoted.head()
# Out:
# Pivoted dataset shape: (53697, 36)
#    station_id station_name station_number  \
# 0           1     AMERICAN       A0714010
# 1           1     AMERICAN       A0714010
# 2           1     AMERICAN       A0714010
# 3           1     AMERICAN       A0714010
# 4           1     AMERICAN       A0714010
#
#                          full_station_name   station_type  latitude  \
# 0  American River at Water Treatment Plant  Surface Water   38.5596
# 1  American River at Water Treatment Plant  Surface Water   38.5596
# 2  American River at Water Treatment Plant  Surface Water   38.5596
# 3  American River at Water Treatment Plant  Surface Water   38.5596
# 4  American River at Water Treatment Plant  Surface Water   38.5596
#
#    longitude county_name sample_code         sample_date  year  \
# 0  -121.4169  Sacramento  C0114B0005 2014-01-06 12:14:00  2014
# 1  -121.4169  Sacramento  C0115B0005 2015-01-05 11:53:00  2015
# 2  -121.4169  Sacramento  C0117B0081 2017-01-10 14:00:00  2017
# 3  -121.4169  Sacramento  C0118B0005 2018-01-08 11:40:00  2018
# 4  -121.4169  Sacramento  C0119B0011 2019-01-07 14:15:00  2019
#
#    sample_depth_meter  (Bottom) DissolvedOxygen_mg/L  \
# 0                 1.0                            NaN
# 1                 1.0                            NaN
# 2                 1.0                            NaN
# 3                 1.0                            NaN
# 4                 1.0                            NaN
#
#    (Bottom) SpecificConductance_µS/cm  (Bottom) WaterTemperature_°C  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
#
#    (Bottom)Chlorophyll Fluorescence_µg/L  (Bottom)Turbidity_NTU  \
# 0                                    NaN                    NaN
# 1                                    NaN                    NaN
# 2                                    NaN                    NaN
# 3                                    NaN                    NaN
# 4                                    NaN                    NaN
#
#    (Bottom)pH_None  Carbon Dioxide_mg/L  Chlorophyll Fluorescence_µg/L  \
# 0              NaN                  NaN                            NaN
# 1              NaN                  NaN                            NaN
# 2              NaN                  NaN                            NaN
# 3              NaN                  NaN                            NaN
# 4              NaN                  NaN                            NaN
#
#    Chlorophyll Volume_µg/L  Discharge_m³/s  DissolvedOxygen_mg/L  \
# 0                      NaN             NaN                 12.18
# 1                      NaN             NaN                 11.74
# 2                      NaN             NaN                 13.04
# 3                      NaN             NaN                 11.12
# 4                      NaN             NaN                 11.46
#
#    ElectricalConductance_µS/cm  Flow, channel_m³/s  Redox Potential_mV  \
# 0                          NaN                 NaN                 NaN
# 1                          NaN                 NaN                 NaN
# 2                          NaN                 NaN                 NaN
# 3                          NaN                 NaN                 NaN
# 4                          NaN                 NaN                 NaN
#
#    Secchi Depth_m  SoilRedox Potential_mV  \
# 0             NaN                     NaN
# 1             NaN                     NaN
# 2             NaN                     NaN
# 3             NaN                     NaN
# 4             NaN                     NaN
#
#    SpecificConductance (EC w/time)_µS/cm  SpecificConductance_µS/cm  \
# 0                                    NaN                       66.0
# 1                                    NaN                       80.0
# 2                                    NaN                       52.0
# 3                                    NaN                       51.0
# 4                                    NaN                       64.8
#
#    Turbidity (w/time)_NTU  Turbidity_NTU  WaterTemperature (w/time)_°C  \
# 0                     NaN           2.28                           NaN
# 1                     NaN           1.41                           NaN
# 2                     NaN         160.00                           NaN
# 3                     NaN           3.00                           NaN
# 4                     NaN           2.10                           NaN
#
#    WaterTemperature_°C  pH (w/time)_pH units  pH_pH units
# 0                10.18                   NaN         7.60
# 1                10.75                   NaN         7.91
# 2                 9.24                   NaN         7.26
# 3                10.80                   NaN         8.36
# 4                11.00                   NaN          NaN

# %% [markdown]
# Not every parameter was measured at every sampling event.
#
# Some are surface-only (pH, DO, Turbidity),
#
# Some are bottom-only (prefixed with (Bottom)),
#
# Some are occasional (like Redox Potential, Carbon Dioxide, Flow).
#
# So for each sampling event, only a subset of parameters exists — all others appear as NaN.

# %%
pivoted.isnull().sum()/pivoted.shape[0]
# Out:
# station_id                               0.000000
# station_name                             0.000000
# station_number                           0.000000
# full_station_name                        0.000000
# station_type                             0.000000
# latitude                                 0.000000
# longitude                                0.000000
# county_name                              0.000000
# sample_code                              0.000000
# sample_date                              0.000000
# year                                     0.000000
# sample_depth_meter                       0.000000
# (Bottom) DissolvedOxygen_mg/L            0.956292
# (Bottom) SpecificConductance_µS/cm       0.954225
# (Bottom) WaterTemperature_°C             0.956329
# (Bottom)Chlorophyll Fluorescence_µg/L    0.956497
# (Bottom)Turbidity_NTU                    0.954206
# (Bottom)pH_None                          0.954038
# Carbon Dioxide_mg/L                      0.999981
# Chlorophyll Fluorescence_µg/L            0.840326
# Chlorophyll Volume_µg/L                  0.952698
# Discharge_m³/s                           0.982569
# DissolvedOxygen_mg/L                     0.203829
# ElectricalConductance_µS/cm              0.975325
# Flow, channel_m³/s                       0.992271
# Redox Potential_mV                       0.992029
# Secchi Depth_m                           0.787493
# SoilRedox Potential_mV                   0.999926
# SpecificConductance (EC w/time)_µS/cm    0.999926
# SpecificConductance_µS/cm                0.024247
# Turbidity (w/time)_NTU                   0.999963
# Turbidity_NTU                            0.306218
# WaterTemperature (w/time)_°C             0.999963
# WaterTemperature_°C                      0.056074
# pH (w/time)_pH units                     0.999907
# pH_pH units                              0.138332
# dtype: float64

# %%
threshold = 0.8      # keep columns with ≥20 % data present

missing_ratio = pivoted.isna().mean()
keep_cols = missing_ratio[missing_ratio < threshold].index

pivoted_core = pivoted[keep_cols].copy()
print(f"Kept {len(keep_cols)} columns of {len(pivoted.columns)} total.")
# Out:
# Kept 18 columns of 36 total.

# %%
# checking for coverage of core parameters

pivoted_core = pivoted[['DissolvedOxygen_mg/L', 'Secchi Depth_m',
                        'SpecificConductance_µS/cm', 'Turbidity_NTU',
                        'WaterTemperature_°C', 'pH_pH units']]

missing_summary = pivoted_core.isna().sum().sort_values()
coverage = (1 - pivoted_core.isna().mean()) * 100
summary = pd.DataFrame({'Missing Count': missing_summary, 'Coverage (%)': coverage})
print(summary)
# Out:
#                            Missing Count  Coverage (%)
# DissolvedOxygen_mg/L               10945     79.617111
# Secchi Depth_m                     42286     21.250722
# SpecificConductance_µS/cm           1302     97.575284
# Turbidity_NTU                      16443     69.378178
# WaterTemperature_°C                 3011     94.392610
# pH_pH units                         7428     86.166825

# %%
meta_cols = [
    'station_id', 'station_name', 'station_number', 'full_station_name',
    'station_type', 'latitude', 'longitude', 'county_name',
    'sample_code', 'sample_date', 'year', 'sample_depth_meter'
]

# Combine metadata with your core parameters
pivoted_core = pivoted[meta_cols + [
    'DissolvedOxygen_mg/L', 'Secchi Depth_m', 'SpecificConductance_µS/cm',
    'Turbidity_NTU', 'WaterTemperature_°C', 'pH_pH units'
]].copy()


#  Impute missing values for frequent parameters

# Define core parameters for imputation (excluding Secchi Depth - sparse)
core_params = [
    'SpecificConductance_µS/cm',
    'WaterTemperature_°C',
    'pH_pH units',
    'DissolvedOxygen_mg/L',
    'Turbidity_NTU'
]

# Median imputation
for col in core_params:
    median_val = pivoted_core[col].median()
    pivoted_core[col] = pivoted_core[col].fillna(median_val)

# drop Secchi Depth
pivoted_core = pivoted_core.drop(columns=['Secchi Depth_m'], errors='ignore')

print("\n Median imputation complete. Secchi Depth dropped (optional).")
print("Remaining columns:", pivoted_core.columns.tolist())


missing_summary = pivoted_core[core_params].isna().sum()
print("\nMissing values per parameter after imputation:\n", missing_summary)

print("\nSummary of core parameters:")
print(pivoted_core[core_params].describe().round(2))
# Out:
#  Median imputation complete. Secchi Depth dropped (optional).
# Remaining columns: ['station_id', 'station_name', 'station_number', 'full_station_name', 'station_type', 'latitude', 'longitude', 'county_name', 'sample_code', 'sample_date', 'year', 'sample_depth_meter', 'DissolvedOxygen_mg/L', 'SpecificConductance_µS/cm', 'Turbidity_NTU', 'WaterTemperature_°C', 'pH_pH units']
#
# Missing values per parameter after imputation:
#  SpecificConductance_µS/cm    0
# WaterTemperature_°C          0
# pH_pH units                  0
# DissolvedOxygen_mg/L         0
# Turbidity_NTU                0
# dtype: int64
#
# Summary of core parameters:
#        SpecificConductance_µS/cm  WaterTemperature_°C  pH_pH units  \
# count                    53697.0             53697.00     53697.00
# mean                      1941.9                16.97         7.74
# std                       5865.7                 5.25         0.49
# min                          0.0                -0.10         0.00
# 25%                        181.0                12.70         7.50
# 50%                        375.0                17.20         7.71
# 75%                        671.0                21.20         7.94
# max                      48600.0                50.00        14.00
#
#        DissolvedOxygen_mg/L  Turbidity_NTU
# count              53697.00       53697.00
# mean                   8.77          13.28
# std                    1.87          29.06
# min                    0.00           0.00
# 25%                    8.05           5.10
# 50%                    8.86           7.80
# 75%                    9.70          11.60
# max                   20.00        1000.00

# %%
pivoted_core.shape
# Out:
# (53697, 17)

# %%
pivoted_core.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'county_name', 'sample_code',
#        'sample_date', 'year', 'sample_depth_meter', 'DissolvedOxygen_mg/L',
#        'SpecificConductance_µS/cm', 'Turbidity_NTU', 'WaterTemperature_°C',
#        'pH_pH units'],
#       dtype='object')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# --- Define sub-index (qi) calculation functions ---

def qi_dissolved_oxygen(do):
    # Reference range: 0–14 mg/L; >7 mg/L good
    return np.clip((do / 14) * 100, 0, 100)

def qi_pH(ph):
    # Ideal range 6.5–8.5
    if np.isnan(ph):
        return np.nan
    if 6.5 <= ph <= 8.5:
        return 100
    elif ph < 6.5:
        return 100 - ((6.5 - ph) / 6.5) * 100
    else:  # ph > 8.5
        return 100 - ((ph - 8.5) / 8.5) * 100

def qi_conductivity(cond):
    # Lower is better; <1500 µS/cm = good
    return np.clip(100 - (cond / 1500) * 100, 0, 100)

def qi_turbidity(turb):
    # Lower is better; 0–5 = clear, >100 = poor
    return np.clip(100 - (turb / 100) * 100, 0, 100)

def qi_temperature(temp):
    # Ideal around 20°C; tolerance ±5°C
    return np.clip(100 - abs(temp - 20) * 5, 0, 100)

# --- Compute sub-indices for each parameter ---
pivoted_core['qi_DO'] = pivoted_core['DissolvedOxygen_mg/L'].apply(qi_dissolved_oxygen)
pivoted_core['qi_pH'] = pivoted_core['pH_pH units'].apply(qi_pH)
pivoted_core['qi_Cond'] = pivoted_core['SpecificConductance_µS/cm'].apply(qi_conductivity)
pivoted_core['qi_Turb'] = pivoted_core['Turbidity_NTU'].apply(qi_turbidity)
pivoted_core['qi_Temp'] = pivoted_core['WaterTemperature_°C'].apply(qi_temperature)

# --- Assign parameter weights ---
weights = {'qi_DO': 0.3, 'qi_pH': 0.2, 'qi_Cond': 0.2, 'qi_Turb': 0.2, 'qi_Temp': 0.1}

# --- Calculate WQI (weighted average of available sub-indices) ---
def calc_wqi(row):
    qi_values = []
    qi_weights = []
    for param, weight in weights.items():
        if not np.isnan(row[param]):
            qi_values.append(row[param])
            qi_weights.append(weight)
    if len(qi_values) == 0:
        return np.nan
    return np.average(qi_values, weights=qi_weights[:len(qi_values)])

pivoted_core['WQI'] = pivoted_core.apply(calc_wqi, axis=1)

# --- Classify water quality ---
def classify_wqi(wqi):
    if np.isnan(wqi): return np.nan
    elif wqi >= 80: return 'Good'
    elif wqi >= 50: return 'Moderate'
    elif wqi >= 25: return 'Poor'
    else: return 'Very Poor'

pivoted_core['WQI_Class'] = pivoted_core['WQI'].apply(classify_wqi)

# %%
pivoted_core.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'county_name', 'sample_code',
#        'sample_date', 'year', 'sample_depth_meter', 'DissolvedOxygen_mg/L',
#        'SpecificConductance_µS/cm', 'Turbidity_NTU', 'WaterTemperature_°C',
#        'pH_pH units', 'qi_DO', 'qi_pH', 'qi_Cond', 'qi_Turb', 'qi_Temp', 'WQI',
#        'WQI_Class'],
#       dtype='object')

# %%
pivoted_core["WQI_Class"].value_counts()
# Out:
# WQI_Class
# Moderate    30057
# Good        23391
# Poor          249
# Name: count, dtype: int64
